# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import glob

# %%
NS_E14_K69 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/E14_K69.dat', sep='\s+')
NS_E14_K69.columns = ['Frame', 'Distance']
S_E14_K69 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/E14_K69.dat', sep='\s+')
S_E14_K69.columns = ['Frame', 'Distance']

# %%
#transparency = 0.5

# %%
binedges = np.arange(0, 20,0.25)
distance = S_E14_K69 ['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_E14_K69 ['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(-3)-E14', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.18])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_D15_K69 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/D15_K69.dat', sep='\s+')
NS_D15_K69.columns = ['Frame', 'Distance']
S_D15_K69 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/D15_K69.dat', sep='\s+')
S_D15_K69.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_D15_K69 ['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_D15_K69 ['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(-3)-D15', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.12])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_E17_K69 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/E17_K69.dat', sep='\s+')
NS_E17_K69.columns = ['Frame', 'Distance']
S_E17_K69 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/E17_K69.dat', sep='\s+')
S_E17_K69.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_E17_K69 ['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_E17_K69 ['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(-3)-E17', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.45])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_D11_K63 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/D11_K63.dat', sep='\s+')
NS_D11_K63.columns = ['Frame', 'Distance']
S_D11_K63 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/D11_K63.dat', sep='\s+')
S_D11_K63.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_D11_K63 ['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_D11_K63 ['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(3)-D11', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.15])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_D9_K63 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/D9_K63.dat', sep='\s+')
NS_D9_K63.columns = ['Frame', 'Distance']
S_D9_K63 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/D9_K63.dat', sep='\s+')
S_D9_K63.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_D9_K63 ['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_D9_K63 ['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(3)-D9', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.215])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_E22_K63 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/E22_K63.dat', sep='\s+')
NS_E22_K63.columns = ['Frame', 'Distance']
S_E22_K63 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/E22_K63.dat', sep='\s+')
S_E22_K63.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_E22_K63 ['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_E22_K63['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(3)-E22', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.1])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_D11_K69 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/D11_K69.dat', sep='\s+')
NS_D11_K69.columns = ['Frame', 'Distance']
S_D11_K69 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/D11_K69.dat', sep='\s+')
S_D11_K69.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_D11_K69['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_D11_K69['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(-3)-D11', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.125])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_D9_K60 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/D9_K60.dat', sep='\s+')
NS_D9_K60.columns = ['Frame', 'Distance']
S_D9_K60 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/D9_K60.dat', sep='\s+')
S_D9_K60.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_D9_K60['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_D9_K60['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(6)-D9', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.125])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_E7_K60 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/E7_K60.dat', sep='\s+')
NS_E7_K60.columns = ['Frame', 'Distance']
S_E7_K60 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/E7_K60.dat', sep='\s+')
S_E7_K60.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_E7_K60['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_E7_K60['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(6)-E7', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.08])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_E22_K60 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/E22_K60.dat', sep='\s+')
NS_E22_K60.columns = ['Frame', 'Distance']
S_E22_K60 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/E22_K60.dat', sep='\s+')
S_E22_K60.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_E22_K60['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_E22_K60['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(6)-E22', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.2])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_D9_K61 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/D9_K61.dat', sep='\s+')
NS_D9_K61.columns = ['Frame', 'Distance']
S_D9_K61 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/D9_K61.dat', sep='\s+')
S_D9_K61.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_D9_K61['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_D9_K61['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(5)-D9', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.05])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_E7_K61 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/E7_K61.dat', sep='\s+')
NS_E7_K61.columns = ['Frame', 'Distance']
S_E7_K61 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/E7_K61.dat', sep='\s+')
S_E7_K61.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_E7_K61['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_E7_K61['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(5)-E7', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.07])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_E22_K61 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/E22_K61.dat', sep='\s+')
NS_E22_K61.columns = ['Frame', 'Distance']
S_E22_K61 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/E22_K61.dat', sep='\s+')
S_E22_K61.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_E22_K61['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_E22_K61['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(5)-E22', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.06])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_D15_K74 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/D15_K74.dat', sep='\s+')
NS_D15_K74.columns = ['Frame', 'Distance']
S_D15_K74 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/D15_K74.dat', sep='\s+')
S_D15_K74.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_D15_K74['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_D15_K74['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(-8)-D15', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.05])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_E14_K74 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/E14_K74.dat', sep='\s+')
NS_E14_K74.columns = ['Frame', 'Distance']
S_E14_K74 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/E14_K74.dat', sep='\s+')
S_E14_K74.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_E14_K74['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_E14_K74['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt',histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(-8)-E14', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.05])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_E17_K74 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/E17_K74.dat', sep='\s+')
NS_E17_K74.columns = ['Frame', 'Distance']
S_E17_K74 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/E17_K74.dat', sep='\s+')
S_E17_K74.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_E17_K74['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_E17_K74['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(-8)-E17', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.07])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_D15_K76 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/D15_K76.dat', sep='\s+')
NS_D15_K76.columns = ['Frame', 'Distance']
S_D15_K76 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/D15_K76.dat', sep='\s+')
S_D15_K76.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_D15_K76['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_D15_K76['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(-10)-D15', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.04])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches

# %%
NS_E14_K76 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/no_salt/analysis/ES_interaction/dat/E14_K76.dat', sep='\s+')
NS_E14_K76.columns = ['Frame', 'Distance']
S_E14_K76 = pd.read_table('/data/oonwuzul/abp1-arka17_bound/salt/abp1-arka17_800mM_salt/ES_interaction/dat/E14_K76.dat', sep='\s+')
S_E14_K76.columns = ['Frame', 'Distance']

binedges = np.arange(0, 20,0.25)
distance = S_E14_K76['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#332288',label = 'salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

distance = NS_E14_K76['Distance'].values
hist = plt.hist(distance, bins = binedges, color='#CC6677',label = 'no salt', histtype = 'step', linestyle = '--', weights = np.ones(len(distance))*(1/len(distance)))

plt.xlabel(r'Distance ($\AA$)', fontsize=16)
plt.ylabel('Fraction of Frames', fontsize=16)
plt.title('K(-10)-E14', fontsize=16)
plt.legend(frameon=False, fontsize=16)
plt.axis([2,20,0,0.05])

plt.xticks(size=16)
plt.yticks(size=16)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 5

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

plt.show()
# Out:
# Current dimensions: 6.4 x 4.8 inches
# New dimensions: 5 x 3.7499999999999996 inches
