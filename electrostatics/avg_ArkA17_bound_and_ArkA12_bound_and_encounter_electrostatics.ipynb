# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd

# %% [markdown]
# ArkA17 bound values: /data/mcohen3/SH3/notebooks/bound_electrostatics_standardized.ipynb
#
# Short range encounter values: /data/mcohen3/SH3/notebooks/short-range_electrostatic_analysis_graph_ArkA12_binding_800_salt.ipynb
#
# Long range encounter values: /data/mcohen3/SH3/notebooks/long-range_electrostatic_analysis_graph_ArkA12_binding_800_salt.ipynb

# %%
# means of bound and encounter complex simulations for electrostatic interactions

# ArkA17 Bound
bd17_nosalt_long = 6.85
bd17_salt_long = 5.96
bd17_nosalt_short = 2.95
bd17_salt_short = 2.26

# ArkA12 Bound
bd_nosalt_long = 4.17
bd_salt_long = 4.09
bd_nosalt_short = 2.14
bd_salt_short = 1.66

# ArkA12 Encounter
ec_nosalt_long = 4.96
ec_salt_long = 2.41
ec_nosalt_short = 1.24
ec_salt_short = 0.58

# %%
# SEMs of bound and encounter complex simulations for electrostatic interactions

# ArkA17 Bound
bd17_nosalt_long_sem = 0.07
bd17_salt_long_sem = 0.11
bd17_nosalt_short_sem = 0.05
bd17_salt_short_sem = 0.05

# ArkA12 Bound
bd_nosalt_long_sem = 0.04
bd_salt_long_sem = 0.04
bd_nosalt_short_sem = 0.07
bd_salt_short_sem = 0.07

# ArkA12 Encounter
ec_nosalt_long_sem = 0.56
ec_salt_long_sem = 0.38
ec_nosalt_short_sem = 0.20
ec_salt_short_sem = 0.22

# %%
x = np.arange(1)  # X coordinates for each group
#print(x)
width = 0.41
sep = 0.2

plt.figure(figsize=(9,7))
#ax = total_electrostat_frac_bound.mean().plot.bar(yerr=total_electrostat_frac_bound.sem(), width=0.5, rot=45)
#fig = plt.gcf()
#ax.set_ylabel('Avg. # Electrostatic Interactions')
#plt.bar(x - width/2, total_electrostat_frac_bound.mean(), width, 
        #yerr=total_electrostat_frac_bound.sem())

## ArkA17 Bound
# Plotting the "long" bars (only for "nosalt sims")
plt.bar(x - 3*(width + sep) - sep, bd17_nosalt_long, width, 
        bottom=bd17_nosalt_short, edgecolor='#CC6677', facecolor='none', hatch='////', 
        yerr=bd17_nosalt_long_sem, error_kw={'elinewidth': 0.5, "capsize": 1.5, "capthick": 0.5}, linewidth=0.5)

# Plotting the "short" bars (only for "nosalt sims")
plt.bar(x - 3*(width + sep) - sep, bd17_nosalt_short, width, color='#CC6677', edgecolor='#CC6677',
        yerr=bd17_nosalt_short_sem, error_kw={'elinewidth': 0.5, "capsize": 1.5, "capthick": 0.5}, linewidth=0.5)

# Plotting the "long" bars (only for "salt sims")
plt.bar(x - 3*(width + sep) + sep + 0.01, bd17_salt_long, width, 
        bottom=bd17_salt_short, edgecolor='#332288', facecolor='none', hatch='////', 
        yerr=bd17_salt_long_sem, error_kw={'elinewidth': 0.5, "capsize": 1.5, "capthick": 0.5}, linewidth=0.5)

# Plotting the "short" bars (only for "salt sims")
plt.bar(x - 3*(width + sep) + sep + 0.01, bd17_salt_short, width, color='#332288', edgecolor='#332288',
        yerr=bd17_salt_short_sem, error_kw={'elinewidth': 0.5, "capsize": 1.5, "capthick": 0.5}, linewidth=0.5)


## ArkA12 Bound
# Plotting the "long" bars (only for "nosalt sims")
plt.bar(x - 3*width/2 - sep, bd_nosalt_long, width, 
        bottom=bd_nosalt_short, edgecolor='#CC6677', facecolor='none', hatch='////', 
        yerr=bd_nosalt_long_sem, error_kw={'elinewidth': 0.5, "capsize": 1.5, "capthick": 0.5}, linewidth=0.5)

# Plotting the "short" bars (only for "nosalt sims")
plt.bar(x - 3*width/2 - sep, bd_nosalt_short, width, color='#CC6677', edgecolor='#CC6677',
        yerr=bd_nosalt_short_sem, error_kw={'elinewidth': 0.5, "capsize": 1.5, "capthick": 0.5}, linewidth=0.5)

# Plotting the "long" bars (only for "salt sims")
plt.bar(x - width/2 - sep, bd_salt_long, width, 
        bottom=bd_salt_short, edgecolor='#332288', facecolor='none', hatch='////', 
        yerr=bd_salt_long_sem, error_kw={'elinewidth': 0.5, "capsize": 1.5, "capthick": 0.5}, linewidth=0.5)

# Plotting the "short" bars (only for "salt sims")
plt.bar(x - width/2 - sep, bd_salt_short, width, color='#332288', edgecolor='#332288',
        yerr=bd_salt_short_sem, error_kw={'elinewidth': 0.5, "capsize": 1.5, "capthick": 0.5}, linewidth=0.5)

## ArkA12 Encounter
# Plotting the "long" bars (only for "nosalt sims")
plt.bar(x + width/2 + sep, ec_nosalt_long, width, 
        bottom=ec_nosalt_short, edgecolor='#882255', facecolor='none', hatch='////', 
        yerr=ec_nosalt_long_sem, error_kw={'elinewidth': 0.5, "capsize": 1.5, "capthick": 0.5}, linewidth=0.5)

# Plotting the "short" bars (only for "nosalt sims")
plt.bar(x + width/2 + sep, ec_nosalt_short, width, color='#882255', edgecolor='#882255',
        yerr=ec_nosalt_short_sem, error_kw={'elinewidth': 0.5, "capsize": 1.5, "capthick": 0.5}, linewidth=0.5)

# Plotting the "long" bars (only for "salt sims")
plt.bar(x + 3*width/2 + sep, ec_salt_long, width, 
        bottom=ec_salt_short, edgecolor='#88CCEE', facecolor='none', hatch='////', 
        yerr=ec_salt_long_sem, error_kw={'elinewidth': 0.5, "capsize": 1.5, "capthick": 0.5}, linewidth=0.5)

# Plotting the "short" bars (only for "salt sims")
plt.bar(x + 3*width/2 + sep, ec_salt_short, width, color='#88CCEE', edgecolor='#88CCEE',
        yerr=ec_salt_short_sem, error_kw={'elinewidth': 0.5, "capsize": 1.5, "capthick": 0.5}, linewidth=0.5)

plt.xlim((1 - 3.5 * width - 3 * sep) - 4*width,1 + 2*sep)
plt.ylim(0,11)
# Set x-axis ticks as original index
plt.xticks([3*(-width - sep), -width - sep, width + sep], ["ArkA17\nBound", "ArkA12\nBound", "ArkA12\nEncounter"], fontsize=7)
plt.tick_params(bottom=False)
plt.yticks(fontsize=7)

# Add legend, xlabel, ylabel, and title
black_patch = mpatches.Patch(color='black', label='short')
black_hatches = mpatches.Patch(facecolor='none', edgecolor='black', hatch='////', label='long')
plt.legend(fontsize=5.75, frameon=False, handles=[black_hatches, black_patch])      
plt.ylabel('Avg. # of Electrostatic\nInteractions', fontsize=7)
# plt.text(-2.23, 0.15, "no \nsalt", color='white', fontsize=7)
# plt.text(-2.15+width, 0.15, "salt", color='white', fontsize=7)
# plt.text(-1.03, 0.15, "no \nsalt", color='white', fontsize=7)
# plt.text(-0.93+width, 0.15, "salt", color='white', fontsize=7)
# plt.text(0.2, 0.15, "no \nsalt", color='white', fontsize=7)
# plt.text(0.29+width, 0.15, "salt", color='white', fontsize=7)
#plt.title('ArkA17 Bound', fontsize=18)

# Get the current figure
fig = plt.gcf()

# Get the current dimensions
current_width, current_height = fig.get_size_inches()
print(f"Current dimensions: {current_width} x {current_height} inches")

# Define the new width
new_width = 2.25

# Calculate the new height to maintain the aspect ratio
aspect_ratio = current_height / current_width
new_height = new_width * aspect_ratio
print(f"New dimensions: {new_width} x {new_height} inches")

# Set the new figure size
fig.set_size_inches(new_width, new_height)

# Save the figure
plt.savefig('avg_electrostatic_ints.png', dpi=1000, bbox_inches='tight')

plt.show()
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# Current dimensions: 9.0 x 7.0 inches
# New dimensions: 2.25 x 1.75 inches

# %%
long_range = pd.read_csv('/data/mcohen3/SH3/notebooks/ArkA12_EC_long_range_EI_fracs.csv')
short_range = pd.read_csv('/data/mcohen3/SH3/notebooks/ArkA12_EC_short_range_EI_fracs.csv')

# %%
# ArkA12 bound effect of NaCl (TOTAL)
total_nosalt = (short_range["encounter nosalt"]*len(short_range)).dropna().values + (long_range["encounter nosalt"]*len(long_range)).dropna().values
total_salt = (short_range["encounter 800 NaCl"]*len(short_range)).dropna().values + (long_range["encounter 800 NaCl"]*len(long_range)).dropna().values
ArkA12_avg_hb_values = np.concatenate([total_nosalt, total_salt])

#calculate the real difference, no salt minus salt
diff_ArkA12_total = total_nosalt.mean() - total_salt.mean()

print("ArkA12 bound 800 mM NaCl vs no-salt difference = " , diff_ArkA12_total)

num_binding_sims = 50
#sample 10000 times and calculate differences
numsample = 10000
diff_ArkA12_samples = [0]*numsample
diff_ArkA12_samples_larger = [0]*numsample
for sample in range(0,len(diff_ArkA12_samples)):
    random_groups = np.random.permutation(ArkA12_avg_hb_values)
    diff_ArkA12_samples[sample] = (np.mean(random_groups[0:num_binding_sims]) 
             - np.mean(random_groups[num_binding_sims:num_binding_sims 
                                                + num_binding_sims]))
    if diff_ArkA12_samples[sample] >= diff_ArkA12_total:
        diff_ArkA12_samples_larger[sample] = 1

#calculate p-value
pval_diff_ArkA12 = (1 + np.sum(diff_ArkA12_samples_larger))/(numsample + 1)
print("p-value = " , pval_diff_ArkA12)
# Out:
# ArkA12 bound 800 mM NaCl vs no-salt difference =  3.202964099820747
# p-value =  0.00029997000299970003

# %%
print(total_nosalt)
# Out:
# [12.4927146  11.309817    3.34165693  0.7766461   5.2651535   3.56393173
#   5.26393819  0.70064171 11.00088536  9.47850429 14.97587699 17.40861989
#   3.27405403  0.34532752  0.25685299 12.09348019 14.56353837  5.98687818
#   0.45855208  8.43297892  6.85767377  9.89322069  1.65944683  5.04301608
#  11.36040557 14.911529    9.10680984  1.27360195  0.46872897  0.14609075
#   6.77756903  4.58329096  3.51667205  0.43328421  9.58645547  7.16240995
#   9.72394394  1.28183435  6.11885021  8.59760578  9.34616238  8.00905787
#   1.02132486  0.60637597  0.39606404]

# %%
test_df = pd.DataFrame()
test_df['new vals'] = df_bound.loc[df_bound['distance'] < 0.2]['encounter nosalt']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 test_df = pd.DataFrame()
# ----> 2 test_df['new vals'] = df_bound.loc[df_bound['distance'] < 0.2]['encounter nosalt']
#
# NameError: name 'df_bound' is not defined

# %%
test_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
